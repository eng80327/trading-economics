# %% [markdown]
# # Understanding Japan
#
# ## Initialising the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_bond_jgb = pd.read_csv('../Data/Japan/1_Markets/markets_historical_gjgb10_ind.csv', encoding='utf-16')
df_bond_jgb
# Out:
#           Symbol        Date   Open   High    Low  Close
# 0     GJGB10:IND  01/08/2023  0.603  0.614  0.594  0.596
# 1     GJGB10:IND  31/07/2023  0.573  0.612  0.573  0.604
# 2     GJGB10:IND  28/07/2023  0.516  0.579  0.501  0.556
# 3     GJGB10:IND  27/07/2023  0.464  0.465  0.436  0.441
# 4     GJGB10:IND  26/07/2023  0.467  0.472  0.447  0.449
# ...          ...         ...    ...    ...    ...    ...
# 4723  GJGB10:IND  16/03/1984  7.300  7.300  7.300  7.300
# 4724  GJGB10:IND  21/02/1984  7.450  7.450  7.450  7.450
# 4725  GJGB10:IND  15/02/1984  7.430  7.430  7.430  7.430
# 4726  GJGB10:IND  10/02/1984  7.430  7.430  7.430  7.430
# 4727  GJGB10:IND  04/01/1984  7.410  7.410  7.410  7.410
#
# [4728 rows x 6 columns]

# %%
df_bond_jgb['date'] = pd.to_datetime(df_bond_jgb['Date'], format='%d/%m/%Y')
df_bond_jgb.set_index('date', inplace=True)
df_bond_jgb
# Out:
#                 Symbol        Date   Open   High    Low  Close
# date
# 2023-08-01  GJGB10:IND  01/08/2023  0.603  0.614  0.594  0.596
# 2023-07-31  GJGB10:IND  31/07/2023  0.573  0.612  0.573  0.604
# 2023-07-28  GJGB10:IND  28/07/2023  0.516  0.579  0.501  0.556
# 2023-07-27  GJGB10:IND  27/07/2023  0.464  0.465  0.436  0.441
# 2023-07-26  GJGB10:IND  26/07/2023  0.467  0.472  0.447  0.449
# ...                ...         ...    ...    ...    ...    ...
# 1984-03-16  GJGB10:IND  16/03/1984  7.300  7.300  7.300  7.300
# 1984-02-21  GJGB10:IND  21/02/1984  7.450  7.450  7.450  7.450
# 1984-02-15  GJGB10:IND  15/02/1984  7.430  7.430  7.430  7.430
# 1984-02-10  GJGB10:IND  10/02/1984  7.430  7.430  7.430  7.430
# 1984-01-04  GJGB10:IND  04/01/1984  7.410  7.410  7.410  7.410
#
# [4728 rows x 6 columns]

# %%
df_bond_jgb.sort_index(ascending=True)
df_bond_jgb
# Out:
#                 Symbol        Date   Open   High    Low  Close
# date
# 2023-08-01  GJGB10:IND  01/08/2023  0.603  0.614  0.594  0.596
# 2023-07-31  GJGB10:IND  31/07/2023  0.573  0.612  0.573  0.604
# 2023-07-28  GJGB10:IND  28/07/2023  0.516  0.579  0.501  0.556
# 2023-07-27  GJGB10:IND  27/07/2023  0.464  0.465  0.436  0.441
# 2023-07-26  GJGB10:IND  26/07/2023  0.467  0.472  0.447  0.449
# ...                ...         ...    ...    ...    ...    ...
# 1984-03-16  GJGB10:IND  16/03/1984  7.300  7.300  7.300  7.300
# 1984-02-21  GJGB10:IND  21/02/1984  7.450  7.450  7.450  7.450
# 1984-02-15  GJGB10:IND  15/02/1984  7.430  7.430  7.430  7.430
# 1984-02-10  GJGB10:IND  10/02/1984  7.430  7.430  7.430  7.430
# 1984-01-04  GJGB10:IND  04/01/1984  7.410  7.410  7.410  7.410
#
# [4728 rows x 6 columns]

# %%
df_bond_jgb.plot()
# Out:
# <Axes: >
