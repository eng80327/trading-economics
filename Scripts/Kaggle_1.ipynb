# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# # Understanding GDP
#
# Learning about GDP from data from Kaggle

# %%
df = pd.read_csv('../Kaggle/top_six_economies.csv')
df.drop(columns='Unnamed: 0', inplace=True)
df.set_index('Year')
# Out:
#        Country Name  GDP (current US$)  GDP, PPP (current international $)  \
# Year
# 1991  United States       6.158129e+12                        6.158129e+12
# 1992  United States       6.520327e+12                        6.520327e+12
# 1993  United States       6.858559e+12                        6.858559e+12
# 1994  United States       7.287236e+12                        7.287236e+12
# 1995  United States       7.639749e+12                        7.639749e+12
# ...             ...                ...                                 ...
# 2016          India       2.294798e+12                        7.735002e+12
# 2017          India       2.651473e+12                        8.276934e+12
# 2018          India       2.702930e+12                        9.021614e+12
# 2019          India       2.831552e+12                        9.526237e+12
# 2020          India       2.667688e+12                        9.005119e+12
#
#       GDP per capita (current US$)  GDP growth (annual %)  \
# ...

# %%
correlation_matrix =  df.corr(numeric_only=True)
correlation_matrix
# Out:
#                                                         Year  \
# Year                                                1.000000
# GDP (current US$)                                   0.396011
# GDP, PPP (current international $)                  0.508287
# GDP per capita (current US$)                        0.302423
# GDP growth (annual %)                              -0.192119
# Imports of goods and services (% of GDP)            0.414729
# Exports of goods and services (% of GDP)            0.352015
# Central government debt, total (% of GDP)           0.652784
# Total reserves (includes gold, current US$)         0.442838
# Unemployment, total (% of total labor force) (m... -0.160184
# Inflation, consumer prices (annual %)              -0.258794
# Personal remittances, received (% of GDP)           0.112233
# Population, total                                   0.079972
# Population growth (annual %)                       -0.257044
# ...

# %%
high_correlation_pair = {}

# Set the correlation threshold
correlation_threshold = 0.5

# Find columns with correlations greater than the threshold
high_corr_columns = set()
num_columns = len(correlation_matrix.columns)

for i in range(num_columns):
    for j in range(i + 1, num_columns):
        if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
            
            high_correlation_pair[correlation_matrix.columns[i]] = correlation_matrix.columns[j]
            
            high_corr_columns.add(col_i)
            high_corr_columns.add(col_j)

for key, value in high_correlation_pair.items():
    print(f"Key: {key}, Value: {value}")
    
    fdf = df.loc[:,[key, value]]
    #fdf.info()
    
    
fdf = df.loc[:,['Year', 'GDP (current US$)', 'GDP per capita (current US$)']]
# Out:
# Key: Year, Value: Central government debt, total (% of GDP)
# Key: GDP (current US$), Value: GDP per capita (current US$)
# Key: GDP, PPP (current international $), Value: Total reserves (includes gold, current US$)
# Key: GDP per capita (current US$), Value: Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)
# Key: GDP growth (annual %), Value: Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)
# Key: Imports of goods and services (% of GDP), Value: Exports of goods and services (% of GDP)
# Key: Central government debt, total (% of GDP), Value: Total reserves (includes gold, current US$)
# Key: Inflation, consumer prices (annual %), Value: Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)
# Key: Personal remittances, received (% of GDP), Value: Life expectancy at birth, total (years)
# Key: Population, total, Value: Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)
# ...

# %%
fdf
# Out:
#      Year  GDP (current US$)  GDP per capita (current US$)
# 0    1991       6.158129e+12                  24342.258905
# 1    1992       6.520327e+12                  25418.990776
# 2    1993       6.858559e+12                  26387.293734
# 3    1994       7.287236e+12                  27694.853416
# 4    1995       7.639749e+12                  28690.875701
# ..    ...                ...                           ...
# 175  2016       2.294798e+12                   1732.554242
# 176  2017       2.651473e+12                   1980.667020
# 177  2018       2.702930e+12                   1998.259076
# 178  2019       2.831552e+12                   2072.244897
# 179  2020       2.667688e+12                   1933.101069
#
# [180 rows x 3 columns]

# %%
correlation_matrix.loc['Year', 'GDP (current US$)', 'GDP per capita (current US$)']]
